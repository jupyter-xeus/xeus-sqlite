# %%
%LOAD chinook.db

# %%
%VEGA_PLOT_BAR SELECT a.Name, COUNT(*) AS no_albums FROM Album AS al JOIN Artist AS a ON al.ArtistId == a.ArtistId GROUP BY al.ArtistId ORDER BY COUNT(*) DESC LIMIT 10;

# %%
SELECT a.Name, COUNT(*) AS no_albums FROM Album AS al JOIN Artist AS a ON al.ArtistId == a.ArtistId GROUP BY al.ArtistId ORDER BY COUNT(*) DESC LIMIT 10;
# Out:
# +-----------------+-----------+
# | Name            | no_albums |
# +-----------------+-----------+
# | Iron Maiden     | 21        |
# +-----------------+-----------+
# | Led Zeppelin    | 14        |
# +-----------------+-----------+
# | Deep Purple     | 11        |
# +-----------------+-----------+
# | Metallica       | 10        |
# +-----------------+-----------+
# | U2              | 10        |
# +-----------------+-----------+
# | Ozzy Osbourne   | 6         |
# +-----------------+-----------+
# | Pearl Jam       | 5         |
# +-----------------+-----------+
# | Various Artists | 4         |
# +-----------------+-----------+
# | Faith No More   | 4         |
# +-----------------+-----------+
# | Foo Fighters    | 4         |
# +-----------------+-----------+
